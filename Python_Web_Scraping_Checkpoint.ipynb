# %% [markdown]
# **Instructions**
#
# Create a Python script to automate data extraction from Wikipedia pages. The script will retrieve HTML content, extract article titles and text, collect internal links, and consolidate these tasks into one function that accepts a Wikipedia URL.
#
# This will be tested on a specific Wikipedia page to validate functionality.
#
# 1. Write a function to Get and parse html content from a Wikipedia page
#
# 2. Write a function to Extract article title
#
# 3. Write a function to Extract article text for each paragraph with their respective
#
# headings. Map those headings to their respective paragraphs in the dictionary.
#
# 4. Write a function to collect every link that redirects to another Wikipedia page
#
# 5. Wrap all the previous functions into a single function that takes as parameters a Wikipedia link
#
# 6. Test the last function on a Wikipedia page of your choice

# %%
import requests
from bs4 import BeautifulSoup

def get_html_content(url):
    """Fetch and parse HTML content from a Wikipedia page."""
    response = requests.get(url)
    if response.status_code == 200:
        return BeautifulSoup(response.text, "html.parser")
    else:
        raise Exception("Failed to retrieve page")

def extract_title(soup):
    """Extract the article title."""
    title_tag = soup.find("h1", id="firstHeading")
    return title_tag.text.strip() if title_tag else "Title not found"

def extract_text(soup):
    """Extract article text with their respective paragraph headings."""
    content = {}
    current_section = "Introduction"
    paragraphs = []

    for element in soup.find_all(['h2', 'h3', 'p']):
        if element.name in ['h2', 'h3']:
            if paragraphs:
                content[current_section] = " ".join(paragraphs)
                paragraphs = []
            current_section = element.text.strip()
        elif element.name == 'p' and element.text.strip():
            paragraphs.append(element.text.strip())

    if paragraphs:
        content[current_section] = " ".join(paragraphs)

    return content

def extract_internal_links(soup, base_url):
    """Collect all internal Wikipedia links."""
    links = set()
    for link in soup.find_all("a", href=True):
        href = link["href"]
        if href.startswith("/wiki/") and ":" not in href:
            full_link = base_url + href
            links.add(full_link)
    return links

def scrape_wikipedia_page(url):
    """Consolidate all functions to scrape a Wikipedia page."""
    base_url = "https://en.wikipedia.org"
    soup = get_html_content(url)
    title = extract_title(soup)
    text_content = extract_text(soup)
    internal_links = extract_internal_links(soup, base_url)

    return {
        "title": title,
        "text": text_content,
        "internal_links": list(internal_links)
    }

# %%
# Testing the function
test_url = "https://en.wikipedia.org/wiki/Butterfly#:~:text=Butterflies%20navigate%20using%20a%20time,plants%20also%20influence%20butterfly%20behaviour."
data = scrape_wikipedia_page(test_url)

# Printing the title
print("Title:", data["title"], "\n")

# Printing the extracted text with headings
print("Article Content:")
for heading, paragraph in data["text"].items():
    print(f"\n{heading}\n{'-' * len(heading)}")
    print(paragraph)

# Printing internal Wikipedia links
print("\nInternal Wikipedia Links:")
for link in data["internal_links"]:
    print(link, "\n")
# Out:
# Title: Butterfly
#
# Article Content:
#
# Contents
# --------
# Rhopalocera Butterflies are winged insects from the lepidopteran superfamily Papilionoidea, characterized by large, often brightly coloured wings that often fold together when at rest, and a conspicuous, fluttering flight. The oldest butterfly fossils have been dated to the Paleocene, about 56 million years ago, though molecular evidence suggests that they likely originated in the  Cretaceous.[1] Butterflies have a four-stage life cycle, and like other holometabolous insects they undergo complete metamorphosis.[2] Winged adults lay eggs on the food plant on which their larvae, known as caterpillars, will feed. The caterpillars grow, sometimes very rapidly, and when fully developed, pupate in a chrysalis. When metamorphosis is complete, the pupal skin splits, the adult insect climbs out, expands its wings to dry, and flies off. Some butterflies, especially in the tropics, have several generations in a year, while others have a single generation, and a few in cold locations may take several years to pass through their entire life cycle.[3] Butterflies are often polymorphic, and many species make use of camouflage, mimicry, and aposematism to evade their predators.[4] Some, like the monarch and the painted lady, migrate over long distances. Many butterflies are attacked by parasites or parasitoids, including wasps, protozoans, flies, and other invertebrates, or are preyed upon by other organisms. Some species are pests because in their larval stages they can damage domestic crops or trees; other species are agents of pollination of some plants. Larvae of a few butterflies (e.g., harvesters) eat harmful insects, and a few are predators of ants, while others live as mutualists in association with ants. Culturally, butterflies are a popular motif in the visual and literary arts. The Smithsonian Institution says "butterflies are certainly one of the most appealing creatures in nature".[5]
#
# Etymology
# ---------
# The Oxford English Dictionary derives the word straightforwardly from Old English butorflēoge, butter-fly; similar names in Old Dutch and Old High German show that the name is ancient, but modern Dutch and German use different words (vlinder and Schmetterling) and the common name often varies substantially between otherwise closely related languages. A possible source of the name is the bright yellow male of the brimstone (Gonepteryx rhamni); another is that butterflies were on the wing in meadows during the spring and summer butter season while the grass was growing.[6][7]
#
# Paleontology
# ------------
# The earliest Lepidoptera fossils date to the Triassic-Jurassic boundary, around 200 million years ago.[8] Butterflies evolved from moths, so while the butterflies are monophyletic (forming a single clade), the moths are not. The oldest known butterfly is Protocoeliades kristenseni from the Palaeocene aged Fur Formation of Denmark, approximately 55 million years old, which belongs to the family Hesperiidae (skippers).[9] Molecular clock estimates suggest that butterflies originated sometime in the Late Cretaceous, but only significantly diversified during the Cenozoic,[10][1] with one study suggesting a North American origin for the group.[1] The oldest American butterfly is the Late Eocene Prodryas persephone from the Florissant Fossil Beds,[11][12] approximately 34 million years old.[13]
#
# Taxonomy and phylogeny
# ----------------------
# Butterflies are divided into seven families that contain a total of about 20,000 species. Traditionally, butterflies have been divided into the superfamilies Papilionoidea and the moth-like Hedyloidea. Recent work has discovered that Hedylidae, the only family within Hedyloidea, is nested within the Papilionoidea, meaning that Papilionoidea would be synonymous with Rhopalocera. The relationships between the rest of the 6 families are extremely well resolved, which is summarized in the below cladogram.[1][14][15] Papilionidae Hedylidae Hesperiidae Pieridae Nymphalidae Lycaenidae Riodinidae
#
# General description
# -------------------
# Butterfly adults are characterized by their four scale-covered wings, which give the Lepidoptera their name (Ancient Greek λεπίς lepís, scale + πτερόν pterón, wing). These scales give butterfly wings their colour: they are pigmented with melanins that give them blacks and browns, as well as uric acid derivatives and flavones that give them yellows, but many of the blues, greens, reds and iridescent colours are created by structural coloration produced by the micro-structures of the scales and hairs.[16][17][18][19] As in all insects, the body is divided into three sections: the head, thorax, and abdomen. The thorax is composed of three segments, each with a pair of legs. In most families of butterfly the antennae are clubbed, unlike those of moths which may be threadlike or feathery. The long proboscis can be coiled when not in use for sipping nectar from flowers.[20] Nearly all butterflies are diurnal, have relatively bright colours, and hold their wings vertically above their bodies when at rest, unlike the majority of moths which fly by night, are often cryptically coloured (well camouflaged), and either hold their wings flat (touching the surface on which the moth is standing) or fold them closely over their bodies. Some day-flying moths, such as the hummingbird hawk-moth,[21] are exceptions to these rules.[20][22] Butterfly larvae, caterpillars, have a hard (sclerotised) head with strong mandibles used for cutting their food, most often leaves. They have cylindrical bodies, with ten segments to the abdomen, generally with short prolegs on segments 3–6 and 10; the three pairs of true legs on the thorax have five segments each.[20] Many are well camouflaged; others are aposematic with bright colours and bristly projections containing toxic chemicals obtained from their food plants. The pupa or chrysalis, unlike that of moths, is not wrapped in a cocoon.[20] Many butterflies are sexually dimorphic. Most butterflies have the ZW sex-determination system where females are the heterogametic sex (ZW) and males homogametic (ZZ).[23]
#
# Distribution and migration
# --------------------------
# Butterflies are distributed worldwide except Antarctica, totalling some 18,500 species.[24] Of these, 775 are Nearctic; 7,700 Neotropical; 1,575 Palearctic; 3,650 Afrotropical; and 4,800 are distributed across the combined Oriental and Australian/Oceania regions.[24] The monarch butterfly is native to the Americas, but in the nineteenth century or before, spread across the world, and is now found in Australia, New Zealand, other parts of Oceania, and the Iberian Peninsula. It is not clear how it dispersed; adults may have been blown by the wind or larvae or pupae may have been accidentally transported by humans, but the presence of suitable host plants in their new environment was a necessity for their successful establishment.[25] Many butterflies, such as the painted lady, monarch, and several danaine migrate for long distances. These migrations take place over a number of generations and no single individual completes the whole trip. The eastern North American population of monarchs can travel thousands of miles south-west to overwintering sites in Mexico. There is a reverse migration in the spring.[26][27] It has recently been shown that the British painted lady undertakes a 9,000-mile round trip in a series of steps by up to six successive generations, from tropical Africa to the Arctic Circle — almost double the length of the famous migrations undertaken by monarch.[28] Spectacular large-scale migrations associated with the monsoon are seen in peninsular India.[29] Migrations have been studied in more recent times using wing tags and also using stable hydrogen isotopes.[30][31] Butterflies navigate using a time-compensated sun compass. They can see polarized light and therefore orient even in cloudy conditions. The polarized light near the ultraviolet spectrum appears to be particularly important.[32][33] Many migratory butterflies live in semi-arid areas where breeding seasons are short.[34] The life histories of their host plants also influence butterfly behaviour.[35]
#
# Life cycle
# ----------
# Butterflies in their adult stage can live from a week to nearly a year depending on the species. Many species have long larval life stages while others can remain dormant in their pupal or egg stages and thereby survive winters.[36] The Melissa Arctic (Oeneis melissa) overwinters twice as a caterpillar.[37] Butterflies may have one or more broods per year. The number of generations per year varies from temperate to tropical regions with tropical regions showing a trend towards multivoltinism.[38] Courtship is often aerial and often involves pheromones. Butterflies then land on the ground or on a perch to mate.[20] Copulation takes place tail-to-tail and may last from minutes to hours. Simple photoreceptor cells located at the genitals are important for this and other adult behaviours.[39] The male passes a spermatophore to the female; to reduce sperm competition, he may cover her with his scent, or in some species such as the Apollos (Parnassius) plugs her genital opening to prevent her from mating again.[40] The vast majority of butterflies have a four-stage life cycle: egg, larva (caterpillar), pupa (chrysalis) and imago (adult). In the genera Colias, Erebia, Euchloe, and Parnassius, a small number of species are known that reproduce semi-parthenogenetically; when the female dies, a partially developed larva emerges from her abdomen.[41] Butterfly eggs are protected by a hard-ridged outer layer of shell, called the chorion. This is lined with a thin coating of wax which prevents the egg from drying out before the larva has had time to fully develop. Each egg contains a number of tiny funnel-shaped openings at one end, called micropyles; the purpose of these holes is to allow sperm to enter and fertilize the egg. Butterfly eggs vary greatly in size and shape between species, but are usually upright and finely sculptured. Some species lay eggs singly, others in batches. Many females produce between one hundred and two hundred eggs.[41] Butterfly eggs are fixed to a leaf with a special glue which hardens rapidly. As it hardens it contracts, deforming the shape of the egg. This glue is easily seen surrounding the base of every egg forming a meniscus. The nature of the glue has been little researched but in the case of Pieris brassicae, it begins as a pale yellow granular secretion containing acidophilic proteins. This is viscous and darkens when exposed to air, becoming a water-insoluble, rubbery material which soon sets solid.[42] Butterflies in the genus Agathymus do not fix their eggs to a leaf; instead, the newly laid eggs fall to the base of the plant.[43] Eggs are almost invariably laid on plants. Each species of butterfly has its own host plant range and while some species of butterfly are restricted to just one species of plant, others use a range of plant species, often including members of a common family.[44] In some species, such as the great spangled fritillary, the eggs are deposited close to but not on the food plant. This most likely happens when the egg overwinters before hatching and where the host plant loses its leaves in winter, as do violets in this example.[45] The egg stage lasts a few weeks in most butterflies, but eggs laid close to winter, especially in temperate regions, go through a diapause (resting) stage, and the hatching may take place only in spring.[46] Some temperate region butterflies, such as the Camberwell beauty, lay their eggs in the spring and have them hatch in the summer.[47] Butterfly larvae, or caterpillars, consume plant leaves and spend practically all of their time searching for and eating food. Although most caterpillars are herbivorous, a few species are predators: Spalgis epius eats scale insects,[48] while lycaenids such as Liphyra brassolis are myrmecophilous, eating ant larvae.[49] Some larvae, especially those of the Lycaenidae, form mutual associations with ants. They communicate with the ants using vibrations that are transmitted through the substrate as well as using che ...
#
# Mating
# ------
# When the butterfly Bicyclus anynana is subjected to repeated inbreeding in the laboratory, there is a dramatic decrease in egg hatching.[61]  This severe inbreeding depression is considered to be likely due to a relatively high mutation rate to recessive alleles with substantial damaging effects and infrequent episodes of inbreeding in nature that might otherwise purge such mutations.[61] Although B. anynana experiences inbreeding depression when forcibly inbred in the laboratory it recovers within a few generation when allowed to breed freely.[62]  During mate selection, adult females do not innately avoid or learn to avoid siblings, implying that such detection may not be critical to reproductive fitness.[62]  Inbreeding may persist in B anynana because the probability of encountering close relatives is rare in nature; that is, movement ecology may mask the deleterious effect of inbreeding resulting in relaxation of selection for active inbreeding avoidance behaviors.
#
# Behaviour
# ---------
# Butterflies feed primarily on nectar from flowers. Some also derive nourishment from pollen,[63] tree sap, rotting fruit, dung, decaying flesh, and dissolved minerals in wet sand or dirt. Butterflies are important as pollinators for some species of plants. In general, they do not carry as much pollen load as bees, but they are capable of moving pollen over greater distances.[64] Flower constancy has been observed for at least one species of butterfly.[65] Adult butterflies consume only liquids, ingested through the proboscis. They sip water from damp patches for hydration and feed on nectar from flowers, from which they obtain sugars for energy, and sodium and other minerals vital for reproduction. Several species of butterflies need more sodium than that provided by nectar and are attracted by sodium in salt; they sometimes land on people, attracted by the salt in human sweat. Some butterflies also visit dung and scavenge rotting fruit or carcasses to obtain minerals and nutrients. In many species, this mud-puddling behaviour is restricted to the males, and studies have suggested that the nutrients collected may be provided as a nuptial gift, along with the spermatophore, during mating.[66] In hilltopping, males of some species seek hilltops and ridge tops, which they patrol in search for females. Since it usually occurs in species with low population density, it is assumed these landscape points are used as meeting places to find mates.[67] Butterflies use their antennae to sense the air for wind and scents. The antennae come in various shapes and colours; the hesperiids have a pointed angle or hook to the antennae, while most other families show knobbed antennae. The antennae are richly covered with sensory organs known as sensillae. A butterfly's sense of taste is coordinated by chemoreceptors on the tarsi, or feet, which work only on contact, and are used to determine whether an egg-laying insect's offspring will be able to feed on a leaf before eggs are laid on it.[68] Many butterflies use chemical signals, pheromones; some have specialized scent scales (androconia) or other structures (coremata or "hair pencils" in the Danaidae).[69] Vision is well developed in butterflies and most species are sensitive to the ultraviolet spectrum. Many species show sexual dimorphism in the patterns of UV reflective patches.[70] Colour vision may be widespread but has been demonstrated in only a few species.[71][72] Some butterflies have organs of hearing and some species make stridulatory and clicking sounds.[73] Many species of butterfly maintain territories and actively chase other species or individuals that may stray into them. Some species will bask or perch on chosen perches. The flight styles of butterflies are often characteristic and some species have courtship flight displays. Butterflies can only fly when their temperature is above 27 °C (81 °F); when it is cool, they can position themselves to expose the underside of the wings to the sunlight to heat themselves up. If their body temperature reaches 40 °C (104 °F), they can orientate themselves with the folded wings edgewise to the sun.[74] Basking is an activity which is more common in the cooler hours of the morning. Some species have evolved dark wingbases to help in gathering more heat and this is especially evident in alpine forms.[75] As in many other insects, the lift generated by butterflies is more than can be accounted for by steady-state, non-transitory aerodynamics. Studies using Vanessa atalanta in a wind tunnel show that they use a wide variety of aerodynamic mechanisms to generate force. These include wake capture, vortices at the wing edge, rotational mechanisms and the Weis-Fogh 'clap-and-fling' mechanism. Butterflies are able to change from one mode to another rapidly.[76]
#
# Ecology
# -------
# Butterflies are threatened in their early stages by parasitoids and in all stages by predators, diseases and environmental factors. Braconid and other parasitic wasps lay their eggs in lepidopteran eggs or larvae and the wasps' parasitoid larvae devour their hosts, usually pupating inside or outside the desiccated husk. Most wasps are very specific about their host species and some have been used as biological controls of pest butterflies like the large white butterfly.[77] When the small cabbage white was accidentally introduced to New Zealand, it had no natural enemies. In order to control it, some pupae that had been parasitised by a chalcid wasp were imported, and natural control was thus regained.[78] Some flies lay their eggs on the outside of caterpillars and the newly hatched fly larvae bore their way through the skin and feed in a similar way to the parasitoid wasp larvae.[79] Predators of butterflies include ants, spiders, wasps, and birds.[80] Caterpillars are also affected by a range of bacterial, viral and fungal diseases, and only a small percentage of the butterfly eggs laid ever reach adulthood.[79] The bacterium Bacillus thuringiensis has been used in sprays to reduce damage to crops by the caterpillars of the large white butterfly, and the entomopathogenic fungus Beauveria bassiana has proved effective for the same purpose.[81] Queen Alexandra's birdwing, found in Papua New Guinea, is the largest butterfly in the world. The species is endangered, and is one of only three insects (the other two being butterflies as well) to be listed on Appendix I of CITES, making international trade illegal.[82] Butterflies protect themselves from predators by a variety of means. Chemical defences are widespread and are mostly based on chemicals of plant origin. In many cases the plants themselves evolved these toxic substances as protection against herbivores. Butterflies have evolved mechanisms to sequester these plant toxins and use them instead in their own defence.[83] These defence mechanisms are effective only if they are well advertised; this has led to the evolution of bright colours in unpalatable butterflies (aposematism). This signal is commonly mimicked by other butterflies, usually only females. A Batesian mimic imitates another species to enjoy the protection of that species' aposematism.[84] The common Mormon of India has female morphs which imitate the unpalatable red-bodied swallowtails, the common rose and the crimson rose.[85] Müllerian mimicry occurs when aposematic species evolve to resemble each other, presumably to reduce predator sampling rates; Heliconius butterflies from the Americas are a good example.[84] Camouflage is found in many butterflies. Some like the oakleaf butterfly and autumn leaf are remarkable imitations of leaves.[86] As caterpillars, many defend themselves by freezing and appearing like sticks or branches.[87] Others have deimatic behaviours, such as rearing up and waving their front ends which are marked with eyespots as if they were snakes.[88] Some papilionid caterpillars such as the giant swallowtail (Papilio cresphontes) resemble bird droppings so as to be passed over by predators.[89] Some caterpillars have hairs and bristly structures that provide protection while others are gregarious and form dense aggregations.[84] Some species are myrmecophiles, forming mutualistic associations with ants and gaining their protection.[90] Behavioural defences include perching and angling the wings to reduce shadow and avoid being conspicuous. Some female Nymphalid butterflies guard their eggs from parasitoidal wasps.[91] The Lycaenidae have a false head consisting of eyespots and small tails (false antennae) to deflect attack from the more vital head region. These may also cause ambush predators such as spiders to approach from the wrong end, enabling the butterflies to detect attacks promptly.[92][93] Many butterflies have eyespots on the wings; these too may deflect attacks, or may serv ...
#
# Declining numbers
# -----------------
# Declining butterfly populations have been noticed in many areas of the world, and this phenomenon is consistent with the rapidly decreasing insect populations around the world. At least in the Western United States, this collapse in the number of most species of butterflies has been determined to be driven by global climate change, specifically, by warmer autumns.[103][104] Butterfly populations in the United States declined by 22% between 2000 and 2020, mainly because of habitat loss, pesticides and climate change.[105]
#
# In art and literature
# ---------------------
# Butterflies have appeared in art from 3500 years ago in ancient Egypt.[106] In hunting scenes, butterflies were sometimes included in a way that suggested life, freedom, and the strength to escape capture, creating a balance to scenes concerned with death and upholding ma'at. They also were suggestive of regeneration or rebirth and protection. Certain butterflies, such as the tiger butterfly,  may have been associated with solar deities, particularly Ra. The tiger butterfly also would have a particular resemblance to the ankh, due to its black body and wingtips, that was likely noted by the Ancient Egyptians. Butterflies may also have been understood as one of the deceased's guides in the afterlife.[107] In the ancient Mesoamerican city of Teotihuacan, the brilliantly coloured image of the butterfly was carved into many temples, buildings, jewellery, and emblazoned on incense burners. The butterfly was sometimes depicted with the maw of a jaguar, and some species were considered to be the reincarnations of the souls of dead warriors. The close association of butterflies with fire and warfare persisted into the Aztec civilisation; evidence of similar jaguar-butterfly images has been found among the Zapotec and Maya civilisations.[108] Butterflies are widely used in objects of art and jewellery: mounted in frames, embedded in resin, displayed in bottles, laminated in paper, and used in some mixed media artworks and furnishings.[109] The Norwegian naturalist Kjell Sandved compiled a photographic Butterfly Alphabet containing all 26 letters and the numerals 0 to 9 from the wings of butterflies.[110] The butterfly is a symbol of being transgender, because of the transformation from caterpillar to winged adult.[111] Sir John Tenniel drew a famous illustration of Alice meeting a caterpillar for Lewis Carroll's Alice in Wonderland, c. 1865. The caterpillar is seated on a toadstool and is smoking a hookah; the image can be read as showing either the forelegs of the larva, or as suggesting a face with protruding nose and chin.[6] Eric Carle's children's book The Very Hungry Caterpillar portrays the larva as an extraordinarily hungry animal, while also teaching children how to count (to five) and the days of the week.[6] A butterfly appeared in one of Rudyard Kipling's Just So Stories, "The Butterfly that Stamped".[112] One of the most popular, and most often recorded, songs by Sweden's eighteenth-century bard, Carl Michael Bellman, is "Fjäriln vingad syns på Haga" (The butterfly wingèd's seen in Haga), one of his Fredman's Songs.[113] Madam Butterfly is a 1904 opera by Giacomo Puccini about a romantic young Japanese bride who is deserted by her American officer husband soon after they are married. It was based on an 1898 short story by John Luther Long.[114]
#
# In mythology and folklore
# -------------------------
# According to Lafcadio Hearn, a butterfly was seen in Japan as the personification of a person's soul; whether they be living, dying, or already dead. One Japanese superstition says that if a butterfly enters your guest room and perches behind the bamboo screen, the person whom you most love is coming to see you. Large numbers of butterflies are viewed as bad omens. When Taira no Masakado was secretly preparing his famous revolt, a vast a swarm of butterflies appeared in Kyoto. The people were frightened, thinking the apparition to be a portent of coming evil.[115] Diderot's Encyclopédie cites butterflies as a symbol for the soul. A Roman sculpture depicts a butterfly exiting the mouth of a dead man, representing the Roman belief that the soul leaves through the mouth.[116] In line with this, the ancient Greek word for "butterfly" is ψυχή (psȳchē), which primarily means "soul" or "mind".[117] According to Mircea Eliade, some of the Nagas of Manipur claim ancestry from a butterfly.[118] In some cultures, butterflies symbolise rebirth.[119] In the English county of Devon, people once hurried to kill the first butterfly of the year, to avoid a year of bad luck.[120] In the Philippines, a lingering black or dark butterfly or moth in the house is taken to mean an impending or recent death in the family.[121] Several American states have chosen an official state butterfly.[122]
#
# Collecting, recording, and rearing
# ----------------------------------
# "Collecting" means preserving dead specimens, not keeping butterflies as pets.[123][124] Collecting butterflies was once a popular hobby; it has now largely been replaced by photography, recording, and rearing butterflies for release into the wild.[6][dubious – discuss][full citation needed] The zoological illustrator Frederick William Frohawk succeeded in rearing all the butterfly species found in Britain, at a rate of four per year, to enable him to draw every stage of each species. He published the results in the folio sized handbook The Natural History of British Butterflies in 1924.[6] Butterflies and moths can be reared for recreation or for release.[125]
#
# In technology
# -------------
# Study of the structural coloration of the wing scales of swallowtail butterflies has led to the development of more efficient light-emitting diodes,[126] and is inspiring nanotechnology research to produce paints that do not use toxic pigments and the development of new display technologies.[127]
#
# Internal Wikipedia Links:
# https://en.wikipedia.org/wiki/Large_blue
#
# https://en.wikipedia.org/wiki/Hepialoidea
#
# https://en.wikipedia.org/wiki/Opera
#
# https://en.wikipedia.org/wiki/Pheromone
#
# https://en.wikipedia.org/wiki/Taxonomy_of_the_Lepidoptera
#
# https://en.wikipedia.org/wiki/Lacturidae
#
# https://en.wikipedia.org/wiki/Nymphalidae
#
# https://en.wikipedia.org/wiki/Eyespot_(mimicry)
#
# https://en.wikipedia.org/wiki/Transposable_element
#
# https://en.wikipedia.org/wiki/Substrate_(biology)
#
# https://en.wikipedia.org/wiki/Wikimedia_Commons
#
# https://en.wikipedia.org/wiki/Wake_capture
#
# https://en.wikipedia.org/wiki/Glyphipterigidae
#
# https://en.wikipedia.org/wiki/Mimesis_(biology)
#
# https://en.wikipedia.org/wiki/Spiracle_(arthropods)
#
# https://en.wikipedia.org/wiki/Drepanidae
#
# https://en.wikipedia.org/wiki/Censer
#
# https://en.wikipedia.org/wiki/Pigment
#
# https://en.wikipedia.org/wiki/S2CID_(identifier)
#
# https://en.wikipedia.org/wiki/Hedylidae
#
# https://en.wikipedia.org/wiki/Bibcode_(identifier)
#
# https://en.wikipedia.org/wiki/Inbreeding_depression
#
# https://en.wikipedia.org/wiki/Geometroidea
#
# https://en.wikipedia.org/wiki/Sclerotin
#
# https://en.wikipedia.org/wiki/Light-emitting_diode
#
# https://en.wikipedia.org/wiki/Iridescence
#
# https://en.wikipedia.org/wiki/Pollen
#
# https://en.wikipedia.org/wiki/Palaeosetidae
#
# https://en.wikipedia.org/wiki/Gonepteryx_rhamni
#
# https://en.wikipedia.org/wiki/Ancient_Greek
#
# https://en.wikipedia.org/wiki/Omen
#
# https://en.wikipedia.org/wiki/Great_spangled_fritillary
#
# https://en.wikipedia.org/wiki/Chrysalis
#
# https://en.wikipedia.org/wiki/Papilio_cresphontes
#
# https://en.wikipedia.org/wiki/Glossary_of_entomology_terms
#
# https://en.wikipedia.org/wiki/Sensillum
#
# https://en.wikipedia.org/wiki/Taylor_%26_Francis
#
# https://en.wikipedia.org/wiki/Nepticulidae
#
# https://en.wikipedia.org/wiki/Winged_insects
#
# https://en.wikipedia.org/wiki/The_Very_Hungry_Caterpillar
#
# https://en.wikipedia.org/wiki/Pupa
#
# https://en.wikipedia.org/wiki/Structural_coloration
#
# https://en.wikipedia.org/wiki/Giacomo_Puccini
#
# https://en.wikipedia.org/wiki/Notodontidae
#
# https://en.wikipedia.org/wiki/Lasiocampidae
#
# https://en.wikipedia.org/wiki/Old_High_German
#
# https://en.wikipedia.org/wiki/Ceratomia_amyntor
#
# https://en.wikipedia.org/wiki/New_Scientist
#
# https://en.wikipedia.org/wiki/Prehistoric_Lepidoptera
#
# https://en.wikipedia.org/wiki/Reincarnation
#
# https://en.wikipedia.org/wiki/Wikispecies
#
# https://en.wikipedia.org/wiki/Animal_navigation
#
# https://en.wikipedia.org/wiki/Oyamel
#
# https://en.wikipedia.org/wiki/Euchloe
#
# https://en.wikipedia.org/wiki/Bacillus_thuringiensis
#
# https://en.wikipedia.org/wiki/Opostegidae
#
# https://en.wikipedia.org/wiki/M%C3%BCllerian_mimicry
#
# https://en.wikipedia.org/wiki/Ecdysone
#
# https://en.wikipedia.org/wiki/Holocene
#
# https://en.wikipedia.org/wiki/Latreille
#
# https://en.wikipedia.org/wiki/Erebia
#
# https://en.wikipedia.org/wiki/Hummingbird_hawk-moth
#
# https://en.wikipedia.org/wiki/Just_So_Stories
#
# https://en.wikipedia.org/wiki/Lift_(force)
#
# https://en.wikipedia.org/wiki/Exoporia
#
# https://en.wikipedia.org/wiki/Yponomeutoidea
#
# https://en.wikipedia.org/wiki/Lepidopteran
#
# https://en.wikipedia.org/wiki/Grizzled_skipper
#
# https://en.wikipedia.org/wiki/Wasp
#
# https://en.wikipedia.org/wiki/Geometer_moth
#
# https://en.wikipedia.org/wiki/Papilio_machaon
#
# https://en.wikipedia.org/wiki/Ermine_moth
#
# https://en.wikipedia.org/wiki/Dudgeonea
#
# https://en.wikipedia.org/wiki/Noctuidae
#
# https://en.wikipedia.org/wiki/Aididae
#
# https://en.wikipedia.org/wiki/Bee
#
# https://en.wikipedia.org/wiki/Abdomen#Arthropoda
#
# https://en.wikipedia.org/wiki/Palaeocene
#
# https://en.wikipedia.org/wiki/Zygaenoidea
#
# https://en.wikipedia.org/wiki/Maya_civilisation
#
# https://en.wikipedia.org/wiki/Aenigmatineidae
#
# https://en.wikipedia.org/wiki/Entomopathogenic_fungus
#
# https://en.wikipedia.org/wiki/Honeydew_(secretion)
#
# https://en.wikipedia.org/wiki/Aerodynamics
#
# https://en.wikipedia.org/wiki/Encyclopedia_Americana
#
# https://en.wikipedia.org/wiki/Eupterotidae
#
# https://en.wikipedia.org/wiki/Acanthopteroctetidae
#
# https://en.wikipedia.org/wiki/Immidae
#
# https://en.wikipedia.org/wiki/Lasiocampoidea
#
# https://en.wikipedia.org/wiki/Pieridae
#
# https://en.wikipedia.org/wiki/Viola_(plant)
#
# https://en.wikipedia.org/wiki/Eriocottidae
#
# https://en.wikipedia.org/wiki/List_of_butterflies_of_North_America
#
# https://en.wikipedia.org/wiki/Australasian_realm
#
# https://en.wikipedia.org/wiki/Noctuoidea
#
# https://en.wikipedia.org/wiki/Pterolonchidae
#
# https://en.wikipedia.org/wiki/Liphyra_brassolis
#
# https://en.wikipedia.org/wiki/Oenosandridae
#
# https://en.wikipedia.org/wiki/Synonym_(taxonomy)
#
# https://en.wikipedia.org/wiki/Elachistidae
#
# https://en.wikipedia.org/wiki/Epicopeiidae
#
# https://en.wikipedia.org/wiki/Hesperiidae
#
# https://en.wikipedia.org/wiki/Isle_of_Wight
#
# https://en.wikipedia.org/wiki/Choreutidae
#
# https://en.wikipedia.org/wiki/Mud-puddling
#
# https://en.wikipedia.org/wiki/Saturniidae
#
# https://en.wikipedia.org/wiki/Tropics
#
# https://en.wikipedia.org/wiki/Whalleyana
#
# https://en.wikipedia.org/wiki/Non-coding_DNA
#
# https://en.wikipedia.org/wiki/Metamorphosis
#
# https://en.wikipedia.org/wiki/List_of_butterflies_of_Trinidad_and_Tobago
#
# https://en.wikipedia.org/wiki/Lewis_Carroll
#
# https://en.wikipedia.org/wiki/Heliodinidae
#
# https://en.wikipedia.org/wiki/Oeneis_melissa
#
# https://en.wikipedia.org/wiki/Lophocoronoidea
#
# https://en.wikipedia.org/wiki/Sphingidae
#
# https://en.wikipedia.org/wiki/Apolysis
#
# https://en.wikipedia.org/wiki/Clade
#
# https://en.wikipedia.org/wiki/Old_Dutch
#
# https://en.wikipedia.org/wiki/List_of_endangered_insects#Other_Lepidoptera_species
#
# https://en.wikipedia.org/wiki/Smithsonian_Institution
#
# https://en.wikipedia.org/wiki/Bagworm_moth
#
# https://en.wikipedia.org/wiki/Tortricidae
#
# https://en.wikipedia.org/wiki/Gelechioidea
#
# https://en.wikipedia.org/wiki/Kyoto
#
# https://en.wikipedia.org/wiki/Bedelliidae
#
# https://en.wikipedia.org/wiki/Ra
#
# https://en.wikipedia.org/wiki/Erebidae
#
# https://en.wikipedia.org/wiki/Zapotec_peoples
#
# https://en.wikipedia.org/wiki/Iberian_Peninsula
#
# https://en.wikipedia.org/wiki/Predation
#
# https://en.wikipedia.org/wiki/Norwegians
#
# https://en.wikipedia.org/wiki/Old_English
#
# https://en.wikipedia.org/wiki/Metachanda
#
# https://en.wikipedia.org/wiki/Apple
#
# https://en.wikipedia.org/wiki/Superfamily_(taxonomy)
#
# https://en.wikipedia.org/wiki/Evolution
#
# https://en.wikipedia.org/wiki/Global_climate_change
#
# https://en.wikipedia.org/wiki/Acrolepiidae
#
# https://en.wikipedia.org/wiki/Tineoidea
#
# https://en.wikipedia.org/wiki/Protein
#
# https://en.wikipedia.org/wiki/Hepialidae
#
# https://en.wikipedia.org/wiki/Hydrogen_isotope_biogeochemistry
#
# https://en.wikipedia.org/wiki/Vanessa_cardui
#
# https://en.wikipedia.org/wiki/Thorax_(insect_anatomy)
#
# https://en.wikipedia.org/wiki/Dryandra_moth
#
# https://en.wikipedia.org/wiki/Eriocraniidae
#
# https://en.wikipedia.org/wiki/Peter_Marren
#
# https://en.wikipedia.org/wiki/Carboniferous
#
# https://en.wikipedia.org/wiki/Myrmica
#
# https://en.wikipedia.org/wiki/Papilio_demoleus
#
# https://en.wikipedia.org/wiki/Giant_swallowtail
#
# https://en.wikipedia.org/wiki/List_of_butterflies_of_Australia
#
# https://en.wikipedia.org/wiki/Neogene
#
# https://en.wikipedia.org/wiki/Pieris_brassicae
#
# https://en.wikipedia.org/wiki/Nature_Ecology_and_Evolution
#
# https://en.wikipedia.org/wiki/Seasonal_polyphenism
#
# https://en.wikipedia.org/wiki/Mnesarchaea
#
# https://en.wikipedia.org/wiki/Plant_defense_against_herbivory
#
# https://en.wikipedia.org/wiki/Melitaea_didyma
#
# https://en.wikipedia.org/wiki/Holometabola
#
# https://en.wikipedia.org/wiki/Neoptera
#
# https://en.wikipedia.org/wiki/Australian_painted_lady
#
# https://en.wikipedia.org/wiki/Diapause
#
# https://en.wikipedia.org/wiki/Doi_(identifier)
#
# https://en.wikipedia.org/wiki/Callidulidae
#
# https://en.wikipedia.org/wiki/Parthenogenesis
#
# https://en.wikipedia.org/wiki/National_Center_for_Biotechnology_Information
#
# https://en.wikipedia.org/wiki/Pyraloidea
#
# https://en.wikipedia.org/wiki/Maat
#
# https://en.wikipedia.org/wiki/Turbulence
#
# https://en.wikipedia.org/wiki/Benjamin_Wilkes
#
# https://en.wikipedia.org/wiki/Squamous_epithelium
#
# https://en.wikipedia.org/wiki/Aporia_crataegi
#
# https://en.wikipedia.org/wiki/Parasite
#
# https://en.wikipedia.org/wiki/Beauveria_bassiana
#
# https://en.wikipedia.org/wiki/Neurohormone
#
# https://en.wikipedia.org/wiki/Nectar
#
# https://en.wikipedia.org/wiki/Papua_New_Guinea
#
# https://en.wikipedia.org/wiki/Main_Page
#
# https://en.wikipedia.org/wiki/Wing_coupling_(Lepidoptera_anatomy)
#
# https://en.wikipedia.org/wiki/Himantopteridae
#
# https://en.wikipedia.org/wiki/Gulf_fritillary
#
# https://en.wikipedia.org/wiki/Taira_no_Masakado
#
# https://en.wikipedia.org/wiki/Insect_mouthparts
#
# https://en.wikipedia.org/wiki/Neotropical_realm
#
# https://en.wikipedia.org/wiki/Geometridae
#
# https://en.wikipedia.org/wiki/Manitoba_Museum
#
# https://en.wikipedia.org/wiki/John_Tenniel
#
# https://en.wikipedia.org/wiki/Molecular_clock
#
# https://en.wikipedia.org/wiki/Heteroneura
#
# https://en.wikipedia.org/wiki/Voltinism
#
# https://en.wikipedia.org/wiki/Global_Biodiversity_Information_Facility
#
# https://en.wikipedia.org/wiki/Papilio_polytes
#
# https://en.wikipedia.org/wiki/Manipur
#
# https://en.wikipedia.org/wiki/Integrated_Taxonomic_Information_System
#
# https://en.wikipedia.org/wiki/Deimatic
#
# https://en.wikipedia.org/wiki/Heterobathmia
#
# https://en.wikipedia.org/wiki/Xyloryctidae
#
# https://en.wikipedia.org/wiki/National_Biodiversity_Network
#
# https://en.wikipedia.org/wiki/Fj%C3%A4riln_vingad_syns_p%C3%A5_Haga
#
# https://en.wikipedia.org/wiki/Bombycoidea
#
# https://en.wikipedia.org/wiki/Tischerioidea
#
# https://en.wikipedia.org/wiki/Euploea
#
# https://en.wikipedia.org/wiki/Papilionidae
#
# https://en.wikipedia.org/wiki/Papilionoidea
#
# https://en.wikipedia.org/wiki/Fur_Formation
#
# https://en.wikipedia.org/wiki/Monarch_Butterfly_Biosphere_Reserve
#
# https://en.wikipedia.org/wiki/Incurvariidae
#
# https://en.wikipedia.org/wiki/Camouflage
#
# https://en.wikipedia.org/wiki/Uric_acid
#
# https://en.wikipedia.org/wiki/Gracillarioidea
#
# https://en.wikipedia.org/wiki/Tineodidae
#
# https://en.wikipedia.org/wiki/Torkel_Weis-Fogh
#
# https://en.wikipedia.org/wiki/Cuticle
#
# https://en.wikipedia.org/wiki/Laothoe_populi
#
# https://en.wikipedia.org/wiki/Coremata
#
# https://en.wikipedia.org/wiki/Sematuridae
#
# https://en.wikipedia.org/wiki/Agathiphaga
#
# https://en.wikipedia.org/wiki/Polymorphism_(biology)
#
# https://en.wikipedia.org/wiki/List_of_U.S._state_butterflies
#
# https://en.wikipedia.org/wiki/Pterygota
#
# https://en.wikipedia.org/wiki/Cossidae
#
# https://en.wikipedia.org/wiki/Allele
#
# https://en.wikipedia.org/wiki/Proboscis
#
# https://en.wikipedia.org/wiki/CITES
#
# https://en.wikipedia.org/wiki/Lepidoptera
#
# https://en.wikipedia.org/wiki/Sexual_dimorphism
#
# https://en.wikipedia.org/wiki/Momphidae
#
# https://en.wikipedia.org/wiki/Wind_tunnel
#
# https://en.wikipedia.org/wiki/Habitat_destruction
#
# https://en.wikipedia.org/wiki/Late_Eocene
#
# https://en.wikipedia.org/wiki/Anthelidae
#
# https://en.wikipedia.org/wiki/Parnassius
#
# https://en.wikipedia.org/wiki/CiteSeerX_(identifier)
#
# https://en.wikipedia.org/wiki/Ancient_Egypt
#
# https://en.wikipedia.org/wiki/Prodoxidae
#
# https://en.wikipedia.org/wiki/Cossoidea
#
# https://en.wikipedia.org/wiki/Ecdysis
#
# https://en.wikipedia.org/wiki/Fauna_Europaea
#
# https://en.wikipedia.org/wiki/Mimicry
#
# https://en.wikipedia.org/wiki/The_Butterfly_that_Stamped
#
# https://en.wikipedia.org/wiki/Mandible
#
# https://en.wikipedia.org/wiki/Uraniidae
#
# https://en.wikipedia.org/wiki/Drepanoidea
#
# https://en.wikipedia.org/wiki/Hill-topping_(biology)
#
# https://en.wikipedia.org/wiki/List_of_butterflies_of_Victoria
#
# https://en.wikipedia.org/wiki/Braconidae
#
# https://en.wikipedia.org/wiki/Dave_Goulson
#
# https://en.wikipedia.org/wiki/Pollination
#
# https://en.wikipedia.org/wiki/Cecidosidae
#
# https://en.wikipedia.org/wiki/Acrolophidae
#
# https://en.wikipedia.org/wiki/Prothoracicotropic_hormone
#
# https://en.wikipedia.org/wiki/Ant_colony
#
# https://en.wikipedia.org/wiki/Jurassic
#
# https://en.wikipedia.org/wiki/Florissant_Fossil_Beds_National_Monument
#
# https://en.wikipedia.org/wiki/Madam_Butterfly
#
# https://en.wikipedia.org/wiki/Obtectomera
#
# https://en.wikipedia.org/wiki/Hemolymph
#
# https://en.wikipedia.org/wiki/Oxford_English_Dictionary
#
# https://en.wikipedia.org/wiki/Somabrachyidae
#
# https://en.wikipedia.org/wiki/Oceanian_realm
#
# https://en.wikipedia.org/wiki/Calpodes
#
# https://en.wikipedia.org/wiki/Ypsolophidae
#
# https://en.wikipedia.org/wiki/Encyclop%C3%A9die
#
# https://en.wikipedia.org/wiki/Rudyard_Kipling
#
# https://en.wikipedia.org/wiki/Proleg
#
# https://en.wikipedia.org/wiki/Seta
#
# https://en.wikipedia.org/wiki/Moth
#
# https://en.wikipedia.org/wiki/Butterfly_Alphabet
#
# https://en.wikipedia.org/wiki/Comparison_of_butterflies_and_moths
#
# https://en.wikipedia.org/wiki/Bombycidae
#
# https://en.wikipedia.org/wiki/Nolidae
#
# https://en.wikipedia.org/wiki/Galacticidae
#
# https://en.wikipedia.org/wiki/John_Luther_Long
#
# https://en.wikipedia.org/wiki/Insect_migration
#
# https://en.wikipedia.org/wiki/Lecithoceridae
#
# https://en.wikipedia.org/wiki/Vortices
#
# https://en.wikipedia.org/wiki/Skipper_(butterfly)
#
# https://en.wikipedia.org/wiki/Megaannum
#
# https://en.wikipedia.org/wiki/Naga_people
#
# https://en.wikipedia.org/wiki/Bucculatricidae
#
# https://en.wikipedia.org/wiki/Alucitoidea
#
# https://en.wikipedia.org/wiki/Adeloidea
#
# https://en.wikipedia.org/wiki/Paleogene
#
# https://en.wikipedia.org/wiki/Chitin
#
# https://en.wikipedia.org/wiki/Wikidata
#
# https://en.wikipedia.org/wiki/Thebes,_Egypt
#
# https://en.wikipedia.org/wiki/Jaguar
#
# https://en.wikipedia.org/wiki/Sodium
#
# https://en.wikipedia.org/wiki/PMID_(identifier)
#
# https://en.wikipedia.org/wiki/Scale_insect
#
# https://en.wikipedia.org/wiki/Crambidae
#
# https://en.wikipedia.org/wiki/Batesian_mimicry
#
# https://en.wikipedia.org/wiki/Cosmopterigidae
#
# https://en.wikipedia.org/wiki/The_Journal_of_Research_on_the_Lepidoptera
#
# https://en.wikipedia.org/wiki/Autostichidae
#
# https://en.wikipedia.org/wiki/Schreckensteiniidae
#
# https://en.wikipedia.org/wiki/Ant
#
# https://en.wikipedia.org/wiki/Mircea_Eliade
#
# https://en.wikipedia.org/wiki/Critically_Endangered
#
# https://en.wikipedia.org/wiki/Monotrysia
#
# https://en.wikipedia.org/wiki/Carl_Michael_Bellman
#
# https://en.wikipedia.org/wiki/Lyonetiidae
#
# https://en.wikipedia.org/wiki/Speckled_wood_(butterfly)
#
# https://en.wikipedia.org/wiki/Alice_(Alice%27s_Adventures_in_Wonderland)
#
# https://en.wikipedia.org/wiki/PMC_(identifier)
#
# https://en.wikipedia.org/wiki/Wayback_Machine
#
# https://en.wikipedia.org/wiki/Colias
#
# https://en.wikipedia.org/wiki/Scythrididae
#
# https://en.wikipedia.org/wiki/Holometabolism
#
# https://en.wikipedia.org/wiki/Butterfly_(disambiguation)
#
# https://en.wikipedia.org/wiki/Monophyletic
#
# https://en.wikipedia.org/wiki/Oecophoridae
#
# https://en.wikipedia.org/wiki/Simaethistoidea
#
# https://en.wikipedia.org/wiki/Egg
#
# https://en.wikipedia.org/wiki/Riodinidae
#
# https://en.wikipedia.org/wiki/Thyrididae
#
# https://en.wikipedia.org/wiki/Instar
#
# https://en.wikipedia.org/wiki/Gene
#
# https://en.wikipedia.org/wiki/Nymphalid
#
# https://en.wikipedia.org/wiki/Bunium_bulbocastanum
#
# https://en.wikipedia.org/wiki/Catapaecilma_major
#
# https://en.wikipedia.org/wiki/Anti-predator_adaptation
#
# https://en.wikipedia.org/wiki/Parasitoid
#
# https://en.wikipedia.org/wiki/Brahmaeidae
#
# https://en.wikipedia.org/wiki/Simple_eye_in_invertebrates
#
# https://en.wikipedia.org/wiki/Aposematism
#
# https://en.wikipedia.org/wiki/Pterophoridae
#
# https://en.wikipedia.org/wiki/Melanin
#
# https://en.wikipedia.org/wiki/Defense_in_insects
#
# https://en.wikipedia.org/wiki/Dalceridae
#
# https://en.wikipedia.org/wiki/Nymphalis_antiopa
#
# https://en.wikipedia.org/wiki/Plutellidae
#
# https://en.wikipedia.org/wiki/Imago
#
# https://en.wikipedia.org/wiki/Fly
#
# https://en.wikipedia.org/wiki/List_of_butterflies_of_Menorca
#
# https://en.wikipedia.org/wiki/Devonian
#
# https://en.wikipedia.org/wiki/Millieriidae
#
# https://en.wikipedia.org/wiki/Insect_collecting
#
# https://en.wikipedia.org/wiki/Crypsis
#
# https://en.wikipedia.org/wiki/Richard_Mabey
#
# https://en.wikipedia.org/wiki/Cyclotorna
#
# https://en.wikipedia.org/wiki/Frederick_William_Frohawk
#
# https://en.wikipedia.org/wiki/List_of_butterflies_of_Great_Britain
#
# https://en.wikipedia.org/wiki/Mutualism_(biology)
#
# https://en.wikipedia.org/wiki/Devon
#
# https://en.wikipedia.org/wiki/Eye#Compound_eyes
#
# https://en.wikipedia.org/wiki/Clap-and-fling
#
# https://en.wikipedia.org/wiki/Transgender
#
# https://en.wikipedia.org/wiki/Flannel_moth
#
# https://en.wikipedia.org/wiki/Triassic
#
# https://en.wikipedia.org/wiki/Swallowtail_butterfly
#
# https://en.wikipedia.org/wiki/Decline_in_insect_populations
#
# https://en.wikipedia.org/wiki/Eric_Carle
#
# https://en.wikipedia.org/wiki/Castniidae
#
# https://en.wikipedia.org/wiki/Phiditiidae
#
# https://en.wikipedia.org/wiki/Aglais_io
#
# https://en.wikipedia.org/wiki/Pyralidae
#
# https://en.wikipedia.org/wiki/Diurnal_cycle
#
# https://en.wikipedia.org/wiki/Lycaenidae
#
# https://en.wikipedia.org/wiki/Protozoa
#
# https://en.wikipedia.org/wiki/Encyclopedia_of_Life
#
# https://en.wikipedia.org/wiki/Angangueo
#
# https://en.wikipedia.org/wiki/Adelidae
#
# https://en.wikipedia.org/wiki/Lepidoptera_migration
#
# https://en.wikipedia.org/wiki/Lithopsyche_antiqua
#
# https://en.wikipedia.org/wiki/Micropterigidae
#
# https://en.wikipedia.org/wiki/Neotheora
#
# https://en.wikipedia.org/wiki/Flower_constancy
#
# https://en.wikipedia.org/wiki/Wall_Street_Journal
#
# https://en.wikipedia.org/wiki/Hedyloidea
#
# https://en.wikipedia.org/wiki/Monsoon
#
# https://en.wikipedia.org/wiki/Pachliopta_hector
#
# https://en.wikipedia.org/wiki/Heterogynidae
#
# https://en.wikipedia.org/wiki/Anomoeotidae
#
# https://en.wikipedia.org/wiki/Permian
#
# https://en.wikipedia.org/wiki/Palearctic_realm
#
# https://en.wikipedia.org/wiki/Insect
#
# https://en.wikipedia.org/wiki/Indomalayan_realm
#
# https://en.wikipedia.org/wiki/Silurian
#
# https://en.wikipedia.org/wiki/Blastobasidae
#
# https://en.wikipedia.org/wiki/Antenna_(biology)
#
# https://en.wikipedia.org/wiki/Epermeniidae
#
# https://en.wikipedia.org/wiki/Inbreeding
#
# https://en.wikipedia.org/wiki/Lists_of_Lepidoptera_by_region
#
# https://en.wikipedia.org/wiki/Butterflies_(disambiguation)
#
# https://en.wikipedia.org/wiki/Nearctic_realm
#
# https://en.wikipedia.org/wiki/Paleocene
#
# https://en.wikipedia.org/wiki/Taxonomy_(biology)
#
# https://en.wikipedia.org/wiki/List_of_butterflies_of_India
#
# https://en.wikipedia.org/wiki/BugGuide
#
# https://en.wikipedia.org/wiki/Spalgis_epius
#
# https://en.wikipedia.org/wiki/Biological_life_cycle
#
# https://en.wikipedia.org/wiki/Douglasiidae
#
# https://en.wikipedia.org/wiki/Pattern_formation
#
# https://en.wikipedia.org/wiki/Glossata
#
# https://en.wikipedia.org/wiki/Urodidae
#
# https://en.wikipedia.org/wiki/Braconid
#
# https://en.wikipedia.org/wiki/Palaephatidae
#
# https://en.wikipedia.org/wiki/Tineidae
#
# https://en.wikipedia.org/wiki/Coleophoridae
#
# https://en.wikipedia.org/wiki/Arthropod_leg#Insects
#
# https://en.wikipedia.org/wiki/Sesiidae
#
# https://en.wikipedia.org/wiki/Kjell_B._Sandved
#
# https://en.wikipedia.org/wiki/Alice%27s_Adventures_in_Wonderland
#
# https://en.wikipedia.org/wiki/CITES#Appendix_I
#
# https://en.wikipedia.org/wiki/Endromidae
#
# https://en.wikipedia.org/wiki/Hyblaeidae
#
# https://en.wikipedia.org/wiki/Butterflies
#
# https://en.wikipedia.org/wiki/Myrmecophily
#
# https://en.wikipedia.org/wiki/Hookah
#
# https://en.wikipedia.org/wiki/Pupa#Cocoon
#
# https://en.wikipedia.org/wiki/Countershading
#
# https://en.wikipedia.org/wiki/Sesioidea
#
# https://en.wikipedia.org/wiki/Many-plumed_moth
#
# https://en.wikipedia.org/wiki/Andesiana
#
# https://en.wikipedia.org/wiki/Cretaceous
#
# https://en.wikipedia.org/wiki/Texas_A%26M_University
#
# https://en.wikipedia.org/wiki/Precambrian
#
# https://en.wikipedia.org/wiki/Caterpillar_(Alice%27s_Adventures_in_Wonderland)
#
# https://en.wikipedia.org/wiki/Mimallonoidea
#
# https://en.wikipedia.org/wiki/Queen_Alexandra%27s_birdwing
#
# https://en.wikipedia.org/wiki/Copromorphidae
#
# https://en.wikipedia.org/wiki/Prodryas
#
# https://en.wikipedia.org/wiki/Cambrian
#
# https://en.wikipedia.org/wiki/Euteliidae
#
# https://en.wikipedia.org/wiki/Biomimetics
#
# https://en.wikipedia.org/wiki/Ordovician
#
# https://en.wikipedia.org/wiki/Spermatophore
#
# https://en.wikipedia.org/wiki/Fredman%27s_Songs
#
# https://en.wikipedia.org/wiki/Butterfly
#
# https://en.wikipedia.org/wiki/Larva
#
# https://en.wikipedia.org/wiki/Developmental_biology
#
# https://en.wikipedia.org/wiki/Nepticuloidea
#
# https://en.wikipedia.org/wiki/Monarch_butterfly
#
# https://en.wikipedia.org/wiki/Parasitoid_wasp
#
# https://en.wikipedia.org/wiki/Caterpillar
#
# https://en.wikipedia.org/wiki/Temperateness
#
# https://en.wikipedia.org/wiki/Pseudobistonidae
#
# https://en.wikipedia.org/wiki/Nanotechnology
#
# https://en.wikipedia.org/wiki/Amateur_Entomologists%27_Society
#
# https://en.wikipedia.org/wiki/Epidermis
#
# https://en.wikipedia.org/wiki/Epipyropidae
#
# https://en.wikipedia.org/wiki/Myrmecophile
#
# https://en.wikipedia.org/wiki/Mating_plug
#
# https://en.wikipedia.org/wiki/Monarch_(butterfly)
#
# https://en.wikipedia.org/wiki/Vanessa_atalanta
#
# https://en.wikipedia.org/wiki/Ditrysia
#
# https://en.wikipedia.org/wiki/Carposinidae
#
# https://en.wikipedia.org/wiki/Stridulation
#
# https://en.wikipedia.org/wiki/ISSN_(identifier)
#
# https://en.wikipedia.org/wiki/Miletinae
#
# https://en.wikipedia.org/wiki/JSTOR_(identifier)
#
# https://en.wikipedia.org/wiki/Zygaenidae
#
# https://en.wikipedia.org/wiki/Anthocharis_cardamines
#
# https://en.wikipedia.org/wiki/Androconia
#
# https://en.wikipedia.org/wiki/Heliconius
#
# https://en.wikipedia.org/wiki/Copromorphoidea
#
# https://en.wikipedia.org/wiki/Danainae
#
# https://en.wikipedia.org/wiki/Arrhenophanidae
#
# https://en.wikipedia.org/wiki/Apatelodidae
#
# https://en.wikipedia.org/wiki/Lafcadio_Hearn
#
# https://en.wikipedia.org/wiki/Arthropod
#
# https://en.wikipedia.org/wiki/Agathymus
#
# https://en.wikipedia.org/wiki/Flavones
#
# https://en.wikipedia.org/wiki/INaturalist
#
# https://en.wikipedia.org/wiki/Catalogue_of_Life
#
# https://en.wikipedia.org/wiki/Gelechiidae
#
# https://en.wikipedia.org/wiki/Nuptial_gift
#
# https://en.wikipedia.org/wiki/Thymelicus_sylvestris
#
# https://en.wikipedia.org/wiki/Pachliopta_aristolochiae
#
# https://en.wikipedia.org/wiki/Symbiosis
#
# https://en.wikipedia.org/wiki/Limacodidae
#
# https://en.wikipedia.org/wiki/Eukaryote
#
# https://en.wikipedia.org/wiki/Doleschallia_bisaltide
#
# https://en.wikipedia.org/wiki/Hdl_(identifier)
#
# https://en.wikipedia.org/wiki/List_of_butterflies_of_Tasmania
#
# https://en.wikipedia.org/wiki/Batrachedridae
#
# https://en.wikipedia.org/wiki/Apanteles
#
# https://en.wikipedia.org/wiki/Naturalist
#
# https://en.wikipedia.org/wiki/Teotihuacan
#
# https://en.wikipedia.org/wiki/Brachodidae
#
# https://en.wikipedia.org/wiki/Actinote_zikani
#
# https://en.wikipedia.org/wiki/Australian_Faunal_Directory
#
# https://en.wikipedia.org/wiki/Mutation_rate
#
# https://en.wikipedia.org/wiki/Osmeterium
#
# https://en.wikipedia.org/wiki/Mesoamerica
#
# https://en.wikipedia.org/wiki/Early_Oligocene
#
# https://en.wikipedia.org/wiki/Cimeliidae
#
# https://en.wikipedia.org/wiki/Aztec_civilisation
#
# https://en.wikipedia.org/wiki/Courtship_display
#
# https://en.wikipedia.org/wiki/List_of_butterflies_of_Taiwan
#
# https://en.wikipedia.org/wiki/Roeslerstammiidae
#
# https://en.wikipedia.org/wiki/Parthenos_sylvia
#
# https://en.wikipedia.org/wiki/Doidae
#
# https://en.wikipedia.org/wiki/26th_dynasty
#
# https://en.wikipedia.org/wiki/Afrotropical_realm
#
# https://en.wikipedia.org/wiki/Gonad
#
# https://en.wikipedia.org/wiki/Brassica
#
# https://en.wikipedia.org/wiki/Ankh
#
# https://en.wikipedia.org/wiki/Danaini
#
# https://en.wikipedia.org/wiki/Gracillariidae
#
# https://en.wikipedia.org/wiki/Neopseustidae
#
# https://en.wikipedia.org/wiki/ISBN_(identifier)
#
# https://en.wikipedia.org/wiki/Anomoses
#
# https://en.wikipedia.org/wiki/Lypusidae
#
# https://en.wikipedia.org/wiki/Charles_Thomas_Bingham
#
# https://en.wikipedia.org/wiki/Paleobiology_Database
#
# https://en.wikipedia.org/wiki/Sweden
#
# https://en.wikipedia.org/wiki/Pieris_rapae
#
# https://en.wikipedia.org/wiki/Animal
#
# https://en.wikipedia.org/wiki/ZW_sex-determination_system
#
# https://en.wikipedia.org/wiki/Prototheoridae
#
# https://en.wikipedia.org/wiki/Heliozelidae
#
# https://en.wikipedia.org/wiki/Wikisource
